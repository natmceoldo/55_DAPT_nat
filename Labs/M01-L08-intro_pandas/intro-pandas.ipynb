# %% [markdown]
# ![Ironhack logo](https://i.imgur.com/1QgrNNw.png)
#
# # Lab | Introduction to Pandas
#
# ## Introduction
#
# In the Introduction to Pandas lesson, we learned about the two main data structures in Pandas (Series and DataFrames), how to work with them, how to obtain them from other data structures, and how to perform basic calculations with them.
#
# The goal of this lab is to help you practice the concepts you learned in the lesson and provide you with some hands-on experience working with Pandas.
#
# ## Getting Started
#
# Read the instructions for each cell and provide your answers. Make sure to test your answers in each cell and save. Jupyter Notebook should automatically save your work progress. But it's a good idea to periodically save your work manually just in case.
#
# ## Resources
#
# - [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/)
# - [Intro to Pandas Data Structures](https://pandas.pydata.org/pandas-docs/stable/dsintro.html)
# - [Descriptive Statistics for Pandas DataFrame](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)

# %% [markdown]
# # Introduction to Pandas
#
# Complete the following set of exercises to solidify your knowledge of Pandas fundamentals.

# %% [markdown]
# #### 1. Import Numpy and Pandas and alias them to `np` and `pd` respectively.

# %%
# your code here
import numpy as np
import pandas as pd

# %% [markdown]
# #### 2. Create a Pandas Series containing the elements of the list below.
#
# Expected output:
#
# ````python
#             0     5.7
#             1    75.2
#             2    74.4
#             3    84.0
#             4    66.5
#             5    66.3
#             6    55.8
#             7    75.7
#             8    29.1
#             9    43.7
#             dtype: float64
#
# ````

# %%
lst = [5.7, 75.2, 74.4, 84.0, 66.5, 66.3, 55.8, 75.7, 29.1, 43.7]

# %%
# your code here
series1 = pd.Series(data=lst)
series1
# Out:
# 0     5.7
# 1    75.2
# 2    74.4
# 3    84.0
# 4    66.5
# 5    66.3
# 6    55.8
# 7    75.7
# 8    29.1
# 9    43.7
# dtype: float64

# %% [markdown]
# #### 3. Use indexing to return the third value in the Series above.
#
# *Hint: Remember that indexing begins at 0.*

# %%
# your code here
series1.iloc[2]
# Out:
# 74.4

# %% [markdown]
# #### 4. Create a Pandas DataFrame from the list of lists below. Each sublist should be represented as a row.
#
# Expected output:
#
# |    |    0 |    1 |    2 |    3 |    4 |
# |---:|-----:|-----:|-----:|-----:|-----:|
# |  0 | 53.1 | 95   | 67.5 | 35   | 78.4 |
# |  1 | 61.3 | 40.8 | 30.8 | 37.8 | 87.6 |
# |  2 | 20.6 | 73.2 | 44.2 | 14.6 | 91.8 |
# |  3 | 57.4 |  0.1 | 96.1 |  4.2 | 69.5 |
# |  4 | 83.6 | 20.5 | 85.4 | 22.8 | 35.9 |
# |  5 | 49   | 69   |  0.1 | 31.8 | 89.1 |
# |  6 | 23.3 | 40.7 | 95   | 83.8 | 26.9 |
# |  7 | 27.6 | 26.4 | 53.8 | 88.8 | 68.5 |
# |  8 | 96.6 | 96.4 | 53.4 | 72.4 | 50.1 |
# |  9 | 73.7 | 39   | 43.2 | 81.6 | 34.7 |

# %%
b = [[53.1, 95.0, 67.5, 35.0, 78.4],
     [61.3, 40.8, 30.8, 37.8, 87.6],
     [20.6, 73.2, 44.2, 14.6, 91.8],
     [57.4, 0.1, 96.1, 4.2, 69.5],
     [83.6, 20.5, 85.4, 22.8, 35.9],
     [49.0, 69.0, 0.1, 31.8, 89.1],
     [23.3, 40.7, 95.0, 83.8, 26.9],
     [27.6, 26.4, 53.8, 88.8, 68.5],
     [96.6, 96.4, 53.4, 72.4, 50.1],
     [73.7, 39.0, 43.2, 81.6, 34.7]]

# %%
# your code here
df1 = pd.DataFrame(data=b)
df1
# Out:
#       0     1     2     3     4
# 0  53.1  95.0  67.5  35.0  78.4
# 1  61.3  40.8  30.8  37.8  87.6
# 2  20.6  73.2  44.2  14.6  91.8
# 3  57.4   0.1  96.1   4.2  69.5
# 4  83.6  20.5  85.4  22.8  35.9
# 5  49.0  69.0   0.1  31.8  89.1
# 6  23.3  40.7  95.0  83.8  26.9
# 7  27.6  26.4  53.8  88.8  68.5
# 8  96.6  96.4  53.4  72.4  50.1
# 9  73.7  39.0  43.2  81.6  34.7

# %% [markdown]
# #### 5. Rename the data frame columns based on the names in the list below.
#
# Expected output:
#
# |    |   Score_1 |   Score_2 |   Score_3 |   Score_4 |   Score_5 |
# |---:|----------:|----------:|----------:|----------:|----------:|
# |  0 |      53.1 |      95   |      67.5 |      35   |      78.4 |
# |  1 |      61.3 |      40.8 |      30.8 |      37.8 |      87.6 |
# |  2 |      20.6 |      73.2 |      44.2 |      14.6 |      91.8 |
# |  3 |      57.4 |       0.1 |      96.1 |       4.2 |      69.5 |
# |  4 |      83.6 |      20.5 |      85.4 |      22.8 |      35.9 |
# |  5 |      49   |      69   |       0.1 |      31.8 |      89.1 |
# |  6 |      23.3 |      40.7 |      95   |      83.8 |      26.9 |
# |  7 |      27.6 |      26.4 |      53.8 |      88.8 |      68.5 |
# |  8 |      96.6 |      96.4 |      53.4 |      72.4 |      50.1 |
# |  9 |      73.7 |      39   |      43.2 |      81.6 |      34.7 |

# %%
colnames = ['Score_1', 'Score_2', 'Score_3', 'Score_4', 'Score_5']

# %%
# your code here
#creating a new df with column names
df2 = pd.DataFrame(data=b, columns=colnames)
df2
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %%
#renaming the columns of df1
df1.columns = colnames
df1
# Out:
#    Score_1  Score_2  Score_3  Score_4  Score_5
# 0     53.1     95.0     67.5     35.0     78.4
# 1     61.3     40.8     30.8     37.8     87.6
# 2     20.6     73.2     44.2     14.6     91.8
# 3     57.4      0.1     96.1      4.2     69.5
# 4     83.6     20.5     85.4     22.8     35.9
# 5     49.0     69.0      0.1     31.8     89.1
# 6     23.3     40.7     95.0     83.8     26.9
# 7     27.6     26.4     53.8     88.8     68.5
# 8     96.6     96.4     53.4     72.4     50.1
# 9     73.7     39.0     43.2     81.6     34.7

# %% [markdown]
# #### 6. Create a subset of this data frame that contains only the Score 1, 3, and 5 columns.
#
# Expected output:
#
# |    |   Score_1 |   Score_3 |   Score_5 |
# |---:|----------:|----------:|----------:|
# |  0 |      53.1 |      67.5 |      78.4 |
# |  1 |      61.3 |      30.8 |      87.6 |
# |  2 |      20.6 |      44.2 |      91.8 |
# |  3 |      57.4 |      96.1 |      69.5 |
# |  4 |      83.6 |      85.4 |      35.9 |
# |  5 |      49   |       0.1 |      89.1 |
# |  6 |      23.3 |      95   |      26.9 |
# |  7 |      27.6 |      53.8 |      68.5 |
# |  8 |      96.6 |      53.4 |      50.1 |
# |  9 |      73.7 |      43.2 |      34.7 |

# %%
# your code here
df1_subset = pd.concat([df1['Score_1'], df1['Score_3'], df1['Score_5']], axis=1)
df1_subset
# Out:
#    Score_1  Score_3  Score_5
# 0     53.1     67.5     78.4
# 1     61.3     30.8     87.6
# 2     20.6     44.2     91.8
# 3     57.4     96.1     69.5
# 4     83.6     85.4     35.9
# 5     49.0      0.1     89.1
# 6     23.3     95.0     26.9
# 7     27.6     53.8     68.5
# 8     96.6     53.4     50.1
# 9     73.7     43.2     34.7

# %% [markdown]
# #### 7. From the original data frame, calculate the average Score_3 value.
#
# Expected output:
#
# ````python
#             56.95
# ````

# %%
# your code here
np.mean(df1['Score_3'])
# Out:
# 56.95000000000001

# %% [markdown]
# #### 8. From the original data frame, calculate the maximum Score_4 value.
#
# Expected output:
#
# ````python
#             88.8
# ````

# %%
# your code here
np.max(df1['Score_4'])
# Out:
# 88.8

# %% [markdown]
# #### 9. From the original data frame, calculate the median Score 2 value.
#
# Expected output:
#
# ````python
#             40.75
# ````

# %%
# your code here
np.median(df1['Score_2'])
# Out:
# 40.75

# %% [markdown]
# #### 10. Create a Pandas DataFrame from the dictionary of product orders below.
#
# Expected output:
#
# |    | Description                       |   Quantity |   UnitPrice |   Revenue |
# |---:|:----------------------------------|-----------:|------------:|----------:|
# |  0 | LUNCH BAG APPLE DESIGN            |          1 |        1.65 |      1.65 |
# |  1 | SET OF 60 VINTAGE LEAF CAKE CASES |         24 |        0.55 |     13.2  |
# |  2 | RIBBON REEL STRIPES DESIGN        |          1 |        1.65 |      1.65 |
# |  3 | WORLD WAR 2 GLIDERS ASSTD DESIGNS |       2880 |        0.18 |    518.4  |
# |  4 | PLAYING CARDS JUBILEE UNION JACK  |          2 |        1.25 |      2.5  |
# |  5 | POPCORN HOLDER                    |          7 |        0.85 |      5.95 |
# |  6 | BOX OF VINTAGE ALPHABET BLOCKS    |          1 |       11.95 |     11.95 |
# |  7 | PARTY BUNTING                     |          4 |        4.95 |     19.8  |
# |  8 | JAZZ HEARTS ADDRESS BOOK          |         10 |        0.19 |      1.9  |
# |  9 | SET OF 4 SANTA PLACE SETTINGS     |         48 |        1.25 |     60    |

# %%
orders = {'Description': ['LUNCH BAG APPLE DESIGN',
  'SET OF 60 VINTAGE LEAF CAKE CASES ',
  'RIBBON REEL STRIPES DESIGN ',
  'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
  'PLAYING CARDS JUBILEE UNION JACK',
  'POPCORN HOLDER',
  'BOX OF VINTAGE ALPHABET BLOCKS',
  'PARTY BUNTING',
  'JAZZ HEARTS ADDRESS BOOK',
  'SET OF 4 SANTA PLACE SETTINGS'],
 'Quantity': [1, 24, 1, 2880, 2, 7, 1, 4, 10, 48],
 'UnitPrice': [1.65, 0.55, 1.65, 0.18, 1.25, 0.85, 11.95, 4.95, 0.19, 1.25],
 'Revenue': [1.65, 13.2, 1.65, 518.4, 2.5, 5.95, 11.95, 19.8, 1.9, 60.0]}

# %%
# your code here
df_products = pd.DataFrame(orders)
df_products
# Out:
#                           Description  Quantity  UnitPrice  Revenue
# 0              LUNCH BAG APPLE DESIGN         1       1.65     1.65
# 1  SET OF 60 VINTAGE LEAF CAKE CASES         24       0.55    13.20
# 2         RIBBON REEL STRIPES DESIGN          1       1.65     1.65
# 3   WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18   518.40
# 4    PLAYING CARDS JUBILEE UNION JACK         2       1.25     2.50
# 5                      POPCORN HOLDER         7       0.85     5.95
# 6      BOX OF VINTAGE ALPHABET BLOCKS         1      11.95    11.95
# 7                       PARTY BUNTING         4       4.95    19.80
# 8            JAZZ HEARTS ADDRESS BOOK        10       0.19     1.90
# 9       SET OF 4 SANTA PLACE SETTINGS        48       1.25    60.00

# %% [markdown]
# #### 11. Calculate the total quantity ordered and revenue generated from these orders.
#
# Expected output:
#
# ````python
#             Quantity    2978.0
#             Revenue      637.0
# ````

# %%
# your code here
print(f"Quantity {np.sum(df_products['Quantity'])}")
print(f"Revenue {np.sum(df_products['Revenue'])}")
# Out:
# Quantity 2978
# Revenue 637.0

# %% [markdown]
# #### 12. Obtain the prices of the most expensive and least expensive items ordered and print the difference.
# Expected output:
#
# ````python
#             Most expensive:  11.95
#             Least expensive:  0.18
#             Difference:  11.77
# ````

# %%
# your code here
print(f"Most expensive: {np.max(df_products['UnitPrice'])}")
print(f"Least expensive: {np.min(df_products['UnitPrice'])}")
print(f"Difference: {np.max(df_products['UnitPrice'])-np.min(df_products['UnitPrice'])}")
# Out:
# Most expensive: 11.95
# Least expensive: 0.18
# Difference: 11.77

# %% [markdown]
# # BONUS

# %% [markdown]
# #### 1 Create a random dataframe containing 3 columns and 10 rows.
#
# *Hint: You'll have to use a `numpy.random` method to create random observations*
#
# **Example of output:**
#
# |    |         0 |        1 |        2 |
# |---:|----------:|---------:|---------:|
# |  0 | 0.0883504 | 0.867054 | 0.977949 |
# |  1 | 0.819555  | 0.643927 | 0.122975 |
# |  2 | 0.484618  | 0.515125 | 0.807791 |
# |  3 | 0.539583  | 0.620799 | 0.926963 |
# |  4 | 0.0479896 | 0.772282 | 0.621921 |
# |  5 | 0.1398    | 0.767678 | 0.678816 |
# |  6 | 0.0895157 | 0.242867 | 0.887941 |
# |  7 | 0.160186  | 0.750576 | 0.439416 |
# |  8 | 0.982747  | 0.652903 | 0.575518 |
# |  9 | 0.646373  | 0.523237 | 0.700222 |

# %%
# your code here
random_array = np.random.random([10, 3])
df_random = pd.DataFrame(data=random_array)
df_random
# Out:
#           0         1         2
# 0  0.846649  0.416276  0.361607
# 1  0.674818  0.964029  0.357454
# 2  0.690006  0.992603  0.797993
# 3  0.663459  0.239752  0.248573
# 4  0.861385  0.305576  0.646692
# 5  0.486750  0.445857  0.819033
# 6  0.887920  0.707140  0.296611
# 7  0.429534  0.787284  0.950000
# 8  0.541174  0.752813  0.629904
# 9  0.439158  0.780251  0.872318

# %% [markdown]
# #### 2 Create a random dataframe containing 3 columns and 10 rows with specific column names.
#
# Use `['column1', 'column2', 'column3']` as the column names.
#
# **Example of output:**
#
# |    |   column1 |   column2 |   column3 |
# |---:|----------:|----------:|----------:|
# |  0 |        10 |        21 |        45 |
# |  1 |        32 |        87 |        39 |
# |  2 |        93 |        53 |         8 |
# |  3 |        52 |        77 |        41 |
# |  4 |        72 |        50 |        31 |
# |  5 |        16 |         6 |        41 |
# |  6 |        66 |        33 |        62 |
# |  7 |        97 |        50 |        92 |
# |  8 |        21 |        71 |        42 |
# |  9 |        91 |        97 |        32 |

# %%
# your code here
col_names = ['column1', 'column2', 'column3'] 
df_random.columns = ['column1', 'column2', 'column3']
df_random
# Out:
#     column1   column2   column3
# 0  0.846649  0.416276  0.361607
# 1  0.674818  0.964029  0.357454
# 2  0.690006  0.992603  0.797993
# 3  0.663459  0.239752  0.248573
# 4  0.861385  0.305576  0.646692
# 5  0.486750  0.445857  0.819033
# 6  0.887920  0.707140  0.296611
# 7  0.429534  0.787284  0.950000
# 8  0.541174  0.752813  0.629904
# 9  0.439158  0.780251  0.872318

# %% [markdown]
# #### 3 Create a random dataframe containing N columns and M rows with specific column names.
#
# For this task you'll have to name the columns as `['column1', 'column2', 'column3', ...,'columnN']`. You can use a list comprehension to do that.

# %%
N = 10
M = 30

# your code here
col_names2 = ['column'+str(i) for i in range(1, N+1)]
pd.DataFrame(data=np.random.random([M, N]), columns = col_names2)
# Out:
#      column1   column2   column3   column4   column5   column6   column7  \
# 0   0.685729  0.129895  0.761923  0.536462  0.735560  0.730561  0.333728
# 1   0.603139  0.003376  0.815243  0.170660  0.927473  0.931056  0.785679
# 2   0.048694  0.143970  0.256621  0.989159  0.213325  0.748188  0.813780
# 3   0.076023  0.316844  0.703947  0.202416  0.367444  0.554897  0.601968
# 4   0.740049  0.386987  0.417709  0.638516  0.289638  0.130637  0.197951
# 5   0.051831  0.189529  0.621508  0.790564  0.780951  0.009565  0.865627
# 6   0.019932  0.756352  0.930840  0.638368  0.022157  0.772399  0.233644
# 7   0.098578  0.289647  0.826824  0.023592  0.605675  0.363027  0.531038
# 8   0.708881  0.748727  0.550483  0.350035  0.781261  0.510215  0.856954
# 9   0.204263  0.998463  0.754871  0.930487  0.393624  0.946109  0.967235
# 10  0.346357  0.435517  0.849264  0.276093  0.815882  0.981605  0.294007
# 11  0.980212  0.833917  0.311336  0.693791  0.419567  0.485746  0.100480
# 12  0.331776  0.706301  0.939677  0.638287  0.452050  0.458443  0.473193
# 13  0.996731  0.697289  0.670394  0.686292  0.817879  0.650240  0.970947
# 14  0.939256  0.402779  0.895532  0.918836  0.000456  0.899704  0.185362
# 15  0.395679  0.624808  0.559389  0.289664  0.623099  0.512075  0.435295
# 16  0.766381  0.044474  0.193092  0.117461  0.449776  0.686736  0.559549
# 17  0.214498  0.819609  0.049503  0.987153  0.035195  0.654990  0.347837
# 18  0.197637  0.030291  0.455709  0.068045  0.066157  0.054003  0.771240
# 19  0.051074  0.811078  0.374636  0.610944  0.527496  0.549661  0.909987
# 20  0.544893  0.938080  0.947697  0.560659  0.478786  0.463658  0.979930
# 21  0.175528  0.865850  0.414855  0.400078  0.385177  0.679475  0.115280
# 22  0.484045  0.506428  0.159679  0.931945  0.691954  0.792204  0.479091
# 23  0.827215  0.579854  0.291410  0.668237  0.042006  0.327710  0.134284
# 24  0.348843  0.208929  0.441643  0.160560  0.976159  0.954481  0.027077
# 25  0.238872  0.489797  0.736772  0.238085  0.528714  0.495185  0.211081
# 26  0.566605  0.164624  0.422069  0.564660  0.023828  0.132503  0.526011
# 27  0.517731  0.359653  0.377137  0.207147  0.140907  0.479150  0.922864
# 28  0.513905  0.512420  0.490818  0.653250  0.921421  0.035598  0.601546
# 29  0.549610  0.395935  0.611781  0.117864  0.957664  0.339026  0.423257
#
#      column8   column9  column10
# 0   0.068310  0.241385  0.888649
# 1   0.981148  0.920189  0.970645
# 2   0.904884  0.877181  0.075797
# 3   0.366544  0.445144  0.663197
# 4   0.654139  0.599742  0.754636
# 5   0.275407  0.068110  0.126931
# 6   0.732441  0.239108  0.765337
# 7   0.235134  0.086554  0.406323
# 8   0.400053  0.440614  0.283519
# 9   0.014426  0.557114  0.126050
# 10  0.183413  0.030806  0.850781
# 11  0.026754  0.995976  0.654289
# 12  0.511561  0.867237  0.373253
# 13  0.869614  0.038950  0.085856
# 14  0.215850  0.012271  0.199537
# 15  0.790599  0.389890  0.347227
# 16  0.636842  0.581742  0.615381
# 17  0.716615  0.289786  0.208801
# 18  0.384338  0.193066  0.817552
# 19  0.354617  0.758866  0.342024
# 20  0.414335  0.019470  0.648879
# 21  0.448874  0.502165  0.750590
# 22  0.719158  0.791288  0.476949
# 23  0.120553  0.781181  0.048992
# 24  0.534872  0.421442  0.919451
# 25  0.366440  0.054450  0.127935
# 26  0.174873  0.053960  0.518679
# 27  0.496963  0.901572  0.901066
# 28  0.980918  0.763530  0.570817
# 29  0.943685  0.813724  0.783843
