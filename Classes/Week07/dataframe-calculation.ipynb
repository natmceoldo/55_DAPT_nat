# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DataFrame Calculations

# %% [markdown]
# ## Read DataFrame

# %% [markdown]
# Description:
#
# http://lib.stat.cmu.edu/datasets/sleep

# %%
# Your code here!
df_animals = pd.read_csv('http://www.statsci.org/data/general/sleep.txt', sep = '\t')
df_animals
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 0          Africanelephant  6654.000   5712.0          NaN       NaN
# 1   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 2                ArcticFox     3.385     44.5          NaN       NaN
# 3     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 4            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 57               Treehyrax     2.000     12.3          4.9       0.5
# 58               Treeshrew     0.104      2.5         13.2       2.6
# 59                  Vervet     4.190     58.0          9.7       0.6
# 60            Wateropossum     3.500      3.9         12.8       6.6
# 61    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger
# 0          3.3      38.6      645.0          3         5       3
# ...

# %% [markdown]
# species of animal
#
# body weight in **kg**
#
# brain weight in **g**
#
# slow wave ("nondreaming") sleep **(hrs/day)**
#
# paradoxical ("dreaming") sleep **(hrs/day)**
#
# total sleep **(hrs/day)**  (sum of slow wave and paradoxical sleep)
#
# maximum life span **(years)**
#
# gestation time **(days)**
#
# predation index (1-5)
#                 1 = minimum (least likely to be preyed upon)
#                 5 = maximum (most likely to be preyed upon)
#
# sleep exposure index (1-5)
#                 1 = least exposed (e.g. animal sleeps in a
#                     well-protected den)
#                 5 = most exposed
#
# overall danger index (1-5)
#                 (based on the above two indices and other information)
#                 1 = least danger (from other animals)
#                 5 = most danger (from other animals)
#
# Note: Missing values denoted by -999.0

# %% [markdown]
# # DataFrame Calculations

# %% [markdown]
# ## Performing calculations to create a new column

# %% [markdown]
# ### Using constants

# %%
# criar uma coluna é basicamente o mesmo processo que se faz em um dicionário
# dataframe['key'] = value
df_animals['new_column'] = 1

# %%
df_animals
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 0          Africanelephant  6654.000   5712.0          NaN       NaN
# 1   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 2                ArcticFox     3.385     44.5          NaN       NaN
# 3     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 4            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 57               Treehyrax     2.000     12.3          4.9       0.5
# 58               Treeshrew     0.104      2.5         13.2       2.6
# 59                  Vervet     4.190     58.0          9.7       0.6
# 60            Wateropossum     3.500      3.9         12.8       6.6
# 61    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column
# ...

# %% [markdown]
# ## From lists

# %%
# Your code here!
df_animals['new_column_2'] = [i for i in range(len(df_animals))]
df_animals
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 0          Africanelephant  6654.000   5712.0          NaN       NaN
# 1   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 2                ArcticFox     3.385     44.5          NaN       NaN
# 3     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 4            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 57               Treehyrax     2.000     12.3          4.9       0.5
# 58               Treeshrew     0.104      2.5         13.2       2.6
# 59                  Vervet     4.190     58.0          9.7       0.6
# 60            Wateropossum     3.500      3.9         12.8       6.6
# 61    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# ...

# %% [markdown]
# ## Performing calculations of `columns` * constant

# %%
# Your code here!
df_animals['BrainWT_kg'] = df_animals['BrainWt']/1000
df_animals
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 0          Africanelephant  6654.000   5712.0          NaN       NaN
# 1   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 2                ArcticFox     3.385     44.5          NaN       NaN
# 3     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 4            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 57               Treehyrax     2.000     12.3          4.9       0.5
# 58               Treeshrew     0.104      2.5         13.2       2.6
# 59                  Vervet     4.190     58.0          9.7       0.6
# 60            Wateropossum     3.500      3.9         12.8       6.6
# 61    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# ...

# %% [markdown]
# ## Performing calculations within columns

# %%
# Your code here!
df_animals['ration_brain_body'] = df_animals.BrainWT_kg/df_animals.BodyWt
df_animals
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 0          Africanelephant  6654.000   5712.0          NaN       NaN
# 1   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 2                ArcticFox     3.385     44.5          NaN       NaN
# 3     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 4            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 57               Treehyrax     2.000     12.3          4.9       0.5
# 58               Treeshrew     0.104      2.5         13.2       2.6
# 59                  Vervet     4.190     58.0          9.7       0.6
# 60            Wateropossum     3.500      3.9         12.8       6.6
# 61    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# ...

# %%
df_animals.ration_brain_body.describe()
# Out:
# count    62.000000
# mean      0.009624
# std       0.008915
# min       0.000858
# 25%       0.003103
# 50%       0.006611
# 75%       0.013668
# max       0.039604
# Name: ration_brain_body, dtype: float64

# %%
df_animals[df_animals.ration_brain_body>0.03]
# Out:
#            Species  BodyWt  BrainWt  NonDreaming  Dreaming  TotalSleep  \
# 26  Groundsquirrel   0.101      4.0         10.4       3.4        13.8
# 41       Owlmonkey   0.480     15.5         15.2       1.8        17.0
#
#     LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# 26       9.0       28.0          5         1       3           1
# 41      12.0      140.0          2         2       2           1
#
#     new_column_2  BrainWT_kg  ration_brain_body
# 26            26      0.0040           0.039604
# 41            41      0.0155           0.032292

# %% [markdown]
# ## Sorting results

# %%
# Your code here!
df_animals.sort_values(by='ration_brain_body', ascending=False, inplace=True)

# %%
df_animals
# Out:
#                     Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 26           Groundsquirrel     0.101     4.00         10.4       3.4
# 41                Owlmonkey     0.480    15.50         15.2       1.8
# 31  Lessershort-tailedshrew     0.005     0.14          7.7       1.4
# 49             Rhesusmonkey     6.800   179.00          8.4       1.2
# 32           Littlebrownbat     0.010     0.25         17.9       2.0
# ..                      ...       ...      ...          ...       ...
# 60             Wateropossum     3.500     3.90         12.8       6.6
# 7            Braziliantapir   160.000   169.00          5.2       1.0
# 44                      Pig   192.000   180.00          6.5       1.9
# 11                      Cow   465.000   423.00          3.2       0.7
# 0           Africanelephant  6654.000  5712.00          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# ...

# %% [markdown]
# ## Performing calculations row-wise

# %% [markdown]
# ### Calculate the sum of weights for each animal

# %%
# Your code here!
df_animals[['BodyWt', 'BrainWT_kg']].sum(axis=1)
# Out:
# 26       0.10500
# 41       0.49550
# 31       0.00514
# 49       6.97900
# 32       0.01025
#          ...
# 60       3.50390
# 7      160.16900
# 44     192.18000
# 11     465.42300
# 0     6659.71200
# Length: 62, dtype: float64

# %% [markdown]
# # Conditional Calculations

# %% [markdown]
# ## Assign values based on conditions

# %%
# Your code here!
df_animals['flag_extinção'] = 0 #False
df_animals.loc[df_animals.Danger>=4, 'flag_extinção'] = 1 #True
df_animals
# Out:
#                     Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 26           Groundsquirrel     0.101     4.00         10.4       3.4
# 41                Owlmonkey     0.480    15.50         15.2       1.8
# 31  Lessershort-tailedshrew     0.005     0.14          7.7       1.4
# 49             Rhesusmonkey     6.800   179.00          8.4       1.2
# 32           Littlebrownbat     0.010     0.25         17.9       2.0
# ..                      ...       ...      ...          ...       ...
# 60             Wateropossum     3.500     3.90         12.8       6.6
# 7            Braziliantapir   160.000   169.00          5.2       1.0
# 44                      Pig   192.000   180.00          6.5       1.9
# 11                      Cow   465.000   423.00          3.2       0.7
# 0           Africanelephant  6654.000  5712.00          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# ...

# %%
df_animals.groupby(by = 'flag_extinção').mean().T
# Out:
# flag_extinção               0           1
# BodyWt             170.050674  263.831579
# BrainWt            211.964651  444.202105
# NonDreaming          9.655882    6.285714
# Dreaming             2.447059    0.962500
# TotalSleep          11.978571    6.737500
# LifeSpan            17.415385   24.931579
# Gestation          103.307692  222.500000
# Predation            2.139535    4.526316
# Exposure             1.534884    4.421053
# Danger               1.790698    4.473684
# new_column           1.000000    1.000000
# new_column_2        31.372093   28.526316
# BrainWT_kg           0.211965    0.444202
# ration_brain_body    0.011027    0.006449

# %% [markdown]
# # Quantiles
# *Touching statistics*

# %% [markdown]
# > Percentiles:
#     - q50 means that 50% of your dataset is below that number. That is the median value.
#     - q90 means that 90% of your dataset is below that number.
#     - q10 means that 10% of your dataset is below that number.

# %% [markdown]
# > Calculating the q50

# %%
# Your code here!
df_animals.BodyWt.median()
# Out:
# 3.3425

# %%
df_animals.loc[df_animals.BodyWt>df_animals.BodyWt.median(), :]
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 49            Rhesusmonkey     6.800    179.0          8.4       1.2
# 33                     Man    62.000   1320.0          6.1       1.9
# 5                   Baboon    10.550    179.5          9.1       0.7
# 59                  Vervet     4.190     58.0          9.7       0.6
# 2                ArcticFox     3.385     44.5          NaN       NaN
# 48                  Redfox     4.235     50.4          7.4       2.4
# 42             Patasmonkey    10.000    115.0         10.0       0.9
# 46                 Raccoon     4.288     39.2          NaN       NaN
# 9               Chimpanzee    52.160    440.0          8.3       1.4
# 52                 Roedeer    14.830     98.2          NaN       NaN
# 51  Rockhyrax(Procaviahab)     3.600     21.0          4.9       0.5
# 61    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
# 21                    Goat    27.660    115.0          3.3       0.5
# ...

# %%
df_animals.BodyWt.quantile(0.1)
# Out:
# 0.07760000000000002

# %%
df_animals.BodyWt.quantile([0.1, 0.2, 0.3])
# Out:
# 0.1    0.0776
# 0.2    0.3090
# 0.3    0.9060
# Name: BodyWt, dtype: float64

# %% [markdown]
# ## Binarizing (categorizing) data

# %%
# Your code here!
df_animals['BodyWt_Interval'] = pd.qcut(df_animals.BodyWt, 4, ['P', 'M', 'G', 'GG'])

# %%
df_animals.BodyWt_Interval.value_counts(normalize=True)
# Out:
# P     0.258065
# GG    0.258065
# M     0.241935
# G     0.241935
# Name: BodyWt_Interval, dtype: float64

# %% [markdown]
# > Calculating the threshold for different quantiles

# %%
# Your code here!

df_animals['BodyWt_Interval2'] = pd.cut(df_animals.BodyWt, 4)

# %% [markdown]
# > Selecting (and counting) the observations that are above (or below) that threshold

# %%
# Your code here!
q10 = df_animals.BodyWt.quantile(0.1)

# %%
df_animals.query(f'BodyWt < {q10}')
# Out:
#                     Species  BodyWt  BrainWt  NonDreaming  Dreaming  \
# 31  Lessershort-tailedshrew   0.005     0.14          7.7       1.4
# 32           Littlebrownbat   0.010     0.25         17.9       2.0
# 36                    Mouse   0.023     0.40         11.9       1.3
# 55            Starnosedmole   0.060     1.00          8.1       2.2
# 14      EasternAmericanmole   0.075     1.20          6.3       2.1
# 6               Bigbrownbat   0.023     0.30         15.8       3.9
# 37                Muskshrew   0.048     0.33         10.8       2.0
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# 31         9.1       2.6       21.5          5         2       4           1
# 32        19.9      24.0       50.0          1         1       1           1
# 36        13.2       3.2       19.0          4         1       3           1
# 55        10.3       3.5        NaN          3         1       2           1
# ...

# %% [markdown]
# ## Numpy where

# %%
import numpy as np

# %%
# Your code here!
q95 = df_animals.BodyWt.quantile(0.95)
np.where(df_animals.BodyWt>q95, 'SUPER OVERWEIGHT', 'NORMAL')
# Out:
# array(['NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL',
#        'NORMAL', 'NORMAL', 'NORMAL', 'SUPER OVERWEIGHT', 'NORMAL',
#        'NORMAL', 'NORMAL', 'SUPER OVERWEIGHT', 'SUPER OVERWEIGHT',
#        'NORMAL', 'NORMAL', 'NORMAL', 'NORMAL', 'SUPER OVERWEIGHT'],
#       dtype='<U16')

# %% [markdown]
# > np.where(condition is true, then this value, else this value)

# %%
# Your code here!
q50 = df_animals.BodyWt.quantile(0.50)
q85 = df_animals.BodyWt.quantile(0.85)
q95 = df_animals.BodyWt.quantile(0.95)
df_animals['class'] = np.where(df_animals['BodyWt'] > q95, 'SUPER-OVERWEIGHT',
                           np.where(df_animals['BodyWt'] > q85, 'ALMOST-SUPER-OVERWEIGHT', 
                                   np.where(df_animals['BodyWt'] > q50,'QUASI-ALMOST-SUPER-OVERWEIGHT','NORMAL')))

# %%
df_animals
# Out:
#                     Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 26           Groundsquirrel     0.101     4.00         10.4       3.4
# 41                Owlmonkey     0.480    15.50         15.2       1.8
# 31  Lessershort-tailedshrew     0.005     0.14          7.7       1.4
# 49             Rhesusmonkey     6.800   179.00          8.4       1.2
# 32           Littlebrownbat     0.010     0.25         17.9       2.0
# ..                      ...       ...      ...          ...       ...
# 60             Wateropossum     3.500     3.90         12.8       6.6
# 7            Braziliantapir   160.000   169.00          5.2       1.0
# 44                      Pig   192.000   180.00          6.5       1.9
# 11                      Cow   465.000   423.00          3.2       0.7
# 0           Africanelephant  6654.000  5712.00          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  new_column  \
# ...

# %% [markdown]
# # Bonus:
#
# ## Correlation
#
# *Touching statistics*

# %%
# Your code here!
df_animals.corr()
# Out:
#                      BodyWt   BrainWt  NonDreaming  Dreaming  TotalSleep  \
# BodyWt             1.000000  0.934164    -0.375946 -0.109383   -0.307186
# BrainWt            0.934164  1.000000    -0.369218 -0.105139   -0.358102
# NonDreaming       -0.375946 -0.369218     1.000000  0.514254    0.962715
# Dreaming          -0.109383 -0.105139     0.514254  1.000000    0.727087
# TotalSleep        -0.307186 -0.358102     0.962715  0.727087    1.000000
# LifeSpan           0.302451  0.509253    -0.384432 -0.295745   -0.410202
# Gestation          0.651102  0.747242    -0.594703 -0.450899   -0.631326
# Predation          0.059495  0.033855    -0.318185 -0.447471   -0.395835
# Exposure           0.338274  0.367800    -0.543757 -0.537225   -0.642285
# Danger             0.133581  0.145879    -0.483852 -0.579337   -0.587742
# new_column              NaN       NaN          NaN       NaN         NaN
# new_column_2      -0.293881 -0.315330     0.159300  0.006344    0.097175
# ...
