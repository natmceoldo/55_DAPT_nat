# %% [markdown]
# # Matplotlib e Seaborn
#
# ## Some References
#
# * [Matplotlib Usage Guide](https://matplotlib.org/stable/tutorials/introductory/usage.html)
# * [Matplotlib Named Colors](https://matplotlib.org/3.1.1/gallery/color/named_colors.html)
# * [Visualization With Seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)
# ----

# %%
# !pip3 install seaborn
# !pip3 install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\natmc\appdata\roaming\python\python39\site-packages (0.11.1)
# Requirement already satisfied: pandas>=0.23 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from seaborn) (1.3.0)
# Requirement already satisfied: scipy>=1.0 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from seaborn) (1.7.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from seaborn) (1.21.1)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in c:\users\natmc\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from pandas>=0.23->seaborn) (2021.1)
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\natmc\appdata\roaming\python\python39\site-packages (3.4.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib) (1.21.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\natmc\appdata\roaming\python\python39\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six in c:\users\natmc\appdata\roaming\python\python39\site-packages (from cycler>=0.10->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.0.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'c:\program files\python39\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np

# %%
# Convenção de importação do matplotlib: plt
import matplotlib.pyplot as plt

# %%
# Garante que o plot irá printar na sua tela
# %matplotlib inline

# %% [markdown]
# ---
# ## Matplotlib Basics

# %% [markdown]
# ### A simple example
#
# Matplotlib graphs your data on `~.figure.Figure`\s (i.e., windows, Jupyter
# widgets, etc.), each of which can contain one or more `~.axes.Axes` (i.e., an
# area where points can be specified in terms of x-y coordinates (or theta-r
# in a polar plot, or x-y-z in a 3D plot, etc.).  The most simple way of
# creating a figure with an axes is using `.pyplot.subplots`. We can then use
# `.Axes.plot` to draw some data on the axes:

# %%
# create a figure containing a single axes.
fig, axs = plt.subplots(2, 2, figsize=(20, 10))
fig.suptitle('Gráficozinhos')
# Out:
# Text(0.5, 0.98, 'Gráficozinhos')

# %%
# you don't need it plt.show() on Jupyter // Display all open figures
# plt.show()

# %% [markdown]
# ### Let's add some data

# %% [markdown]
# * Matplotlib Colors: https://matplotlib.org/stable/gallery/color/named_colors.html

# %%
# your code here!
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].plot([1, 2, 3, 4], [1, 0, 2, 5], color='orange')
axs[1].bar([1, 2, 3, 4], [1, 0, 2, 5], color='orange')
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Figure
# * Parts of a figure: https://matplotlib.org/stable/gallery/showcase/anatomy.html

# %%
# an empty figure with no Axes
fig = plt.figure()
fig.suptitle('Título de um gráfico')
# Out:
# Text(0.5, 0.98, 'Título de um gráfico')

# %% [markdown]
# ### Axes
# * This is what you think of as 'a plot', it is the region of the image with the data space;
# * A given figure can contain many Axes, but a given Axes object can only be in one Figure;
# * The Axes contains two (or three in the case of 3D) Axis objects

# %%
# a figure with a single Axes
fig, ax = plt.subplots()

# %%
# a figure with a 2x2 grid of Axes
fig, ax = plt.subplots(2, 2)

# %% [markdown]
# ### Axis

# %%
# your code here!
fig, ax = plt.subplots(2, 2, figsize=(10,6))
ax[1][0].plot([1, 2, 3, 4], [2, 1, 2, 1])
ax[1][0].set(ylim=(0, 5), xlim=(0, 5))
# Out:
# [(0.0, 5.0), (0.0, 5.0)]

# %% [markdown]
# ### Two ways to do the same thing
# **The object-oriented interface and the pyplot interface**
#
# * WAY 1: Explicitly create figures and axes, and call methods on them (the "object-oriented (OO) style").
# * WAY 2: Rely on pyplot to automatically create and manage the figures and axes, and use pyplot functions for plotting (MATLAB-style Interface).
#
# https://jakevdp.github.io/PythonDataScienceHandbook/04.00-introduction-to-matplotlib.html

# %%
# your code here!
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots()
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('Título do gráfico')
ax.legend()

# %%
# your code here!
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.title('Title')
plt.legend()
plt.xlabel('x label')
plt.ylabel('y label')
# Out:
# Text(0, 0.5, 'y label')

# %% [markdown]
# ### Basic Charts

# %% [markdown]
# #### Line Chart
# Line plots can be linear or non-linear depending on the kind of data we have.

# %%
# Criar valores para x e y
x = np.arange(0, 10, 1)
y = np.linspace(0, 5, 10)

# %%
# Plotar valores a partir do módulo pyplot
plt.plot(x, y)

# %%
# Plotar valores a partir do módulo pyplot com algumas configurações

plt.plot(x, y, color='purple', label='linear')
plt.plot(x, y**2, color='orange', label='quadratic')

plt.ylabel('y label')
plt.xlabel('x label')

plt.show()

# %% [markdown]
# #### Scatter Plot
# Scatter plots are very useful to see the relationship between two variables (also known as correlation)

# %%
# your code here!
x =  np.random.randn(10)
y1 =  np.random.randn(10)
y2 = np.random.randn(10)

plt.scatter(x, y1, marker='x')
plt.scatter(x, y2, marker='*')

# %% [markdown]
# #### Pie Charts
#
# It is a circular statistical graphic, which is divided into slices to illustrate numerical proportion of each slice. It is an important business tool to visually see the percentage shares of different components under investigation.

# %%
# your code here!
labels = ['Vegetarians', 'Non-Vegetarians', 'Vegans']
sizes = [40, 45, 15]

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, counterclock=False, explode=(0, 0, 0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x245372cac70>,
#   <matplotlib.patches.Wedge at 0x245372e2c40>,
#   <matplotlib.patches.Wedge at 0x245372e26a0>],
#  [Text(1.0461621742897658, 0.33991867422268784, 'Vegetarians'),
#   Text(-0.7778174593052023, -0.7778174593052024, 'Non-Vegetarians'),
#   Text(-0.5447886197087483, 1.0692078188246834, 'Vegans')],
#  [Text(0.5706339132489631, 0.1854101859396479, '40.0%'),
#   Text(-0.42426406871192845, -0.4242640687119285, '45.0%'),
#   Text(-0.31779336149676973, 0.6237045609810652, '15.0%')])

# %% [markdown]
# ---
# ## Seaborn Basics
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# **Matplotlib Cons**
#
# Matplotlib has proven to be an incredibly useful and popular visualization tool, but even avid users will admit it often leaves much to be desired. There are several valid complaints about Matplotlib that often come up:
#
# * Matplotlib's API is relatively **low level**. Doing sophisticated statistical visualization is possible, but often requires a lot of boilerplate code.
# * Matplotlib predated Pandas by more than a decade, and thus is **not designed for use with Pandas DataFrames**. In order to visualize data from a Pandas DataFrame, you must extract each Series and often concatenate them together into the right format. It would be nicer to have a plotting library that can intelligently use the DataFrame labels in a plot. [Source](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)
#
#
#
# **Relationship to Matplotlib**
# * While you can be productive using only seaborn functions, **full customization of your graphics will require some knowledge of matplotlib’s concepts and API.**
# * One aspect of the learning curve for new users of seaborn will be knowing when dropping down to the matplotlib layer is necessary to achieve a particular customization. On the other hand, users coming from matplotlib will find that much of their knowledge transfers. [Source](https://seaborn.pydata.org/introduction.html)

# %% [markdown]
# ### Matplotlib vs Seaborn

# %%
# Create some data
rng = np.random.RandomState(0)

x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)

# %%
# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='best')

# %%
import seaborn as sns
sns.set()

# %%
# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='best')

# %%
sns.set_style('whitegrid')
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='best')

# %% [markdown]
# **Important!**
#
# * `sns.set()` uses the matplotlib rcParam system and will affect how all matplotlib plots look
# * [Aesthetics](https://seaborn.pydata.org/tutorial/aesthetics.html)

# %% [markdown]
# ### Exploring Charts

# %%
# Load an example dataset
tips = sns.load_dataset("tips") # https://github.com/mwaskom/seaborn-data

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Relational Plot

# %% [markdown]
# Let's understand the relationship between the `total_bill` and the `tips`, grouped by `time`,
# and for each `plot`, lets group by `smokers`, and the size of the marks is based on people on the table represented by `size` variable.

# %%
# your code here!
sns.relplot(data=tips, col='time', x='total_bill', y='tip', style='smoker', hue='smoker', size='size')

# %% [markdown]
# #### Statistical Estimation

# %%
# your code here!
sns.lmplot(data=tips, x='total_bill', y='tip', col='time', hue='smoker')

# %% [markdown]
# #### Informative distributional summaries

# %%
# your code here!
sns.displot(data=tips, x='total_bill', kind='hist', col='time', stat="density")
plt.axvline(tips.total_bill.mean(), color='red')
plt.axvline(tips.total_bill.median(), color='orange')

# %%
sns.displot(data=tips, x='tip', kind='hist', col='time', stat="density")

# %% [markdown]
# #### Categorical Data With Confidence Interval

# %%
# your code here!
sns.catplot(data=tips, kind='bar', x='day', y='total_bill', hue='smoker')

# %% [markdown]
# #### Heatmap

# %%
# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights") # https://github.com/mwaskom/seaborn-data

# %%
flights_long.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_long_pivot = flights_long.pivot(index='month', columns='year', values='passengers')
flights_long_pivot
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
# Draw a heatmap with the numeric values in each cell
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(flights_long_pivot, annot=True, fmt='d', cmap='coolwarm_r', center=200, linewidth=0.5)
fig.suptitle('Total de voos ao longo dos anos e meses')
# Out:
# Text(0.5, 0.98, 'Total de voos ao longo dos anos e meses')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip')

# %%
sns.violinplot(y = 'tip', data=tips, x='smoker', split=True)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='tip'>

# %% [markdown]
# ----
#
# https://seaborn.pydata.org/examples/index.html
